# %% [markdown]
# We present here the figures obtained in the non-convex case (*i.e* using deep learning) for the following paper:
#
# [Preserved central model for faster bidirectional compression in distributed settings](https://arxiv.org/pdf/2102.12528.pdf).
#
# ## Table of Contents
#
# - [A bit of coding](#a-bit-of-coding)
# - [Cifar 10](#cifar10)
# - [Fashion Mnist](#fashion-mnist)
# - [FE Mnist](#fe-mnist)
# - [Mnist](#Mnist)

# %% [markdown]
# # A bit of coding
#
# Below, we code a function that helps to generate and plot all figures.

# %%
# Add below current directory to path
# Notebook cannot import any code without this line !!!!
import sys; sys.path.insert(0, '..')

import numpy as np

from src.deeplearning.NonConvexSettings import *
from src.utils.Utilities import pickle_loader
from src.utils.runner.RunnerUtilities import create_path_and_folders
from src.utils.ErrorPlotter import plot_error_dist

# %%
def regenerate_and_plot_all_figures(dataset: str):
    
    # Some configuration.
    stochastic = True
    nb_devices = 20
    algos = "mcm-vs-existing"
    iid = "iid"
    fraction_sampled_workers = 1
    batch_size = batch_sizes[dataset]
    
    # Getting path to pickle, data ...
    data_path, pickle_path, algos_pickle_path, picture_path = create_path_and_folders(nb_devices, dataset, iid, 
                                                                                      algos,
                                                                                      fraction_sampled_workers)
    
    # Getting the name of the experiments (required to load the correct pickle file).
    exp_name = name_of_the_experiments(dataset, stochastic)
    
    # Loading the pickle file.
    res = pickle_loader("{0}/{1}".format(algos_pickle_path, exp_name))
    obj_min = 0
    
    # Generating, saving, plotting the train loss, the test loss and the accuray.
    plot_error_dist(res.get_loss(np.array(obj_min)), res.names, res.nb_devices, batch_size=batch_size,
                    all_error=res.get_std(np.array(obj_min)), x_legend="Number of passes on data", ylegends="train_loss",
                    picture_name="{0}/{1}_train_losses".format(picture_path, exp_name))
    plot_error_dist(res.get_loss(np.array(obj_min)), res.names, res.nb_devices,
                    batch_size=batch_size, x_points=res.X_number_of_bits, ylegends="train_loss",
                    all_error=res.get_std(np.array(obj_min)), x_legend="Communicated bits",
                    picture_name="{0}/{1}_train_losses_bits".format(picture_path, exp_name))
    plot_error_dist(res.get_test_accuracies(), res.names, res.nb_devices, ylegends="accuracy",
                    all_error=res.get_test_accuracies_std(), x_legend="Number of passes on data", batch_size=batch_size,
                    picture_name="{0}/{1}_test_accuracies".format(picture_path, exp_name))
    plot_error_dist(res.get_test_losses(in_log=True), res.names, res.nb_devices, batch_size=batch_size,
                    all_error=res.get_test_losses_std(in_log=True), x_legend="Number of passes on data", ylegends="test_loss",
                    picture_name="{0}/{1}_test_losses".format(picture_path, exp_name))

# %% [markdown]
# # Cifar 10

# %%
regenerate_and_plot_all_figures("cifar10")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Fashion Mnist

# %%
regenerate_and_plot_all_figures("fashion_mnist")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # FE Mnist

# %%
regenerate_and_plot_all_figures("femnist")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-b4e7603915b7> in <module>
# ----> 1 regenerate_and_plot_all_figures("femnist")
#
# <ipython-input-8-210f871af3ee> in regenerate_and_plot_all_figures(dataset)
#      28                     batch_size=batch_size, x_points=res.X_number_of_bits, ylegends="train_loss",
#      29                     all_error=res.get_std(np.array(obj_min)), x_legend="Communicated bits",
# ---> 30                     picture_name="{0}/{1}_train_losses_bits".format(picture_path, exp_name))
#      31     plot_error_dist(res.get_test_accuracies(), res.names, res.nb_devices, ylegends="accuracy",
#      32                     all_error=res.get_test_accuracies_std(), x_legend="Number of passes on data", batch_size=batch_size,
#
# ~/Github/artemis/src/utils/ErrorPlotter.py in plot_error_dist(all_losses, legend, nb_devices, nb_dim, batch_size, all_error, x_points, x_legend, one_on_two_points, xlabels, ylegends, ylim, omega_c, picture_name)
#      70
#      71         if x_points is not None:
# ---> 72             abscisse = x_points[i]
#      73
#      74         if all_error is not None:
#
# IndexError: list index out of range

# %% [markdown]
# # Mnist

# %%
regenerate_and_plot_all_figures("mnist")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
